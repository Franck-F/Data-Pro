# %% [markdown]
# # Test de L'API LUX

# %%
import lux
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import lux
#       2 import pandas as pd
#
# File c:\Users\Franck\AppData\Local\Programs\Python\Python313\Lib\site-packages\lux\__init__.py:17
#       1 #  Copyright 2019-2020 The Lux Authors.
#       2 #
#       3 #  Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      14
#      15 # Register the commonly used modules (similar to how pandas does it: https://github.com/pandas-dev/pandas/blob/master/pandas/__init__.py)
#      16 from lux.vis.Clause import Clause
# ---> 17 from lux.core.frame import LuxDataFrame
#      18 from lux.core.sqltable import LuxSQLTable
#      19 from lux.core.joinedsqltable import JoinedSQLTable
#
# File c:\Users\Franck\AppData\Local\Programs\Python\Python313\Lib\site-packages\lux\core\__init__.py:16
# ...
